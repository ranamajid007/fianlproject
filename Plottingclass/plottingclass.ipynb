# %%
import numpy as np
from pandas import Series, DataFrame

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.rc('figure', figsize=(10, 6))

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1) #dsa

# %%
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
np.random.seed(12345)

# %%
from numpy.random import randn
plt.plot(randn(50).cumsum(), 'k--')   #k-- is the type of line graph

# %%
_ = ax1.hist(randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))

# %%
plt.show()

# %%
fig, axes = plt.subplots(2, 3) #2 rows 3 columns
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000022E9808D0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000022E09F4A8>]], dtype=object)

# %%
plt.show()

# %%
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
wspace=None, hspace=None)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color='k', alpha=0.5)
        
plt.subplots_adjust(wspace=0, hspace=0)  #w is width and h is height

# %%
plt.show()

# %% [markdown]
# # Colors, Markers and Line Styles

# %%
plt.figure()

# %%
plt.plot(randn(30).cumsum(), 'ko--')  #ko-- is also type of line graphs where circle is end points

# %%
plt.show()

# %%
data = randn(30).cumsum()
plt.plot(data, 'k--', label= 'Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %%
plt.show()

# %% [markdown]
# # Ticks, Labels and Legends

# %%
fig = plt.figure(); #refresh the figure

ax = fig.add_subplot(1, 1, 1)  #by default 1 row, 1 column, location 1
ax.plot(randn(1000).cumsum())
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
rotation=30, fontsize='small')
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')

# %%
plt.show()

# %%
fig = plt.figure(); 
ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')
ax.legend(loc='best')

# %%
plt.show()

# %% [markdown]
# # Annotation and Drawing on subplot

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)  #0.4 is width and 0.15 is length ... alpha is contrast color
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)  #o.15 is skewness
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
color='g', alpha=0.5)
ax.add_patch(rect)  #ax is the generated variable for the subplot
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
plt.show()

# %% [markdown]
# # Saving plots to file

# %%
fig.savefig('figpath.svg')  #output will create a file with .svg format which is similar to xml for figures in web

# %%
fig.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %%
from io import BytesIO
buffer = BytesIO()
plt.savefig(buffer)
plot_data = buffer.getvalue()

# %% [markdown]
# # Plotting functions in Pandas

# %% [markdown]
# #  Line Plots

# %%
plt.close ('all')

# %%
s = Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10)) #plotting a series
s.plot()

# %%
plt.show()

# %%
df = DataFrame(np.random.randn(10, 4).cumsum(0),
columns=['A', 'B', 'C', 'D'],
index=np.arange(0, 100, 10))
df.plot()

# %%
plt.show()

# %% [markdown]
# # Bar Plot

# %%
fig, axes = plt.subplots(2, 1) #2 rows one column
data = Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7)
data.plot(kind='barh', ax=axes[1], color='k', alpha=0.7) #barh is horizontal bar graph

# %%
data
# Out:
# a    0.673135
# b    0.567298
# c    0.259324
# d    0.024760
# e    0.885967
# f    0.722545
# g    0.385868
# h    0.402209
# i    0.408771
# j    0.791503
# k    0.861211
# l    0.734256
# m    0.468749
# n    0.456218
# o    0.882127
# p    0.709978
# dtype: float64

# %%
plt.show()

# %%
df = DataFrame(np.random.rand(6, 4),
index=['one', 'two', 'three', 'four', 'five', 'six'],
columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
df.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-efab5e6235c7> in <module>()
#       1 df = DataFrame(np.random.rand(6, 4),
#       2 index=['one', 'two', 'three', 'four', 'five', 'six'],
# ----> 3 columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
#       4 df
#       5 df.plot(kind='bar')
#
# NameError: name 'pd' is not defined
